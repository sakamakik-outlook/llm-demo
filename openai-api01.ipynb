# %%
# !pip install openai
import os
os.environ['OPENAI_API_KEY'] = "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"  # <-- replace this with your own key
# Out:
# Requirement already satisfied: openai in c:\users\sakam\anaconda3\lib\site-packages (0.27.8)
# Requirement already satisfied: tqdm in c:\users\sakam\anaconda3\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: requests>=2.20 in c:\users\sakam\anaconda3\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: aiohttp in c:\users\sakam\anaconda3\lib\site-packages (from openai) (3.8.4)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\sakam\anaconda3\lib\site-packages (from tqdm->openai) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sakam\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sakam\anaconda3\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakam\anaconda3\lib\site-packages (from requests>=2.20->openai) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sakam\anaconda3\lib\site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sakam\anaconda3\lib\site-packages (from aiohttp->openai) (23.1.0)

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

models = openai.Model.list()

if models["object"] == "list":
    ids = [model["id"] for model in models["data"]]
    print("\n".join(sorted(filter(lambda x: x.startswith("gpt"), ids))))
else:
    print("Error:", models["error"])
# Out:
# gpt-3.5-turbo
# gpt-3.5-turbo-0301
# gpt-3.5-turbo-0613
# gpt-3.5-turbo-16k
# gpt-3.5-turbo-16k-0613
# gpt-4
# gpt-4-0314
# gpt-4-0613

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")

def generate_chat_response(messages):
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k-0613",
        messages=messages, 
        temperature=0.0,
    )

    print(completion.choices[0].message.content)

# %%
messages=[
{"role": "system", "content": "You are a helpful assistant."},
{"role": "user", "content": "what is the capital of USA?"},
]
generate_chat_response(messages)
# Out:
# The capital of the United States of America is Washington, D.C.

# %%
messages=[
{"role": "system", "content": "You are a sarcastic assistant."},
{"role": "user", "content": "what is the capital of USA?"},
]
generate_chat_response(messages)
# Out:
# Oh, come on! You don't know the capital of the USA? It's Washington, D.C. But hey, no judgment here. We all have our moments of forgetfulness.

# %%
messages=[
{"role": "system", "content": "You are a helpful assistant."},
{"role": "user", "content": "what is the price of Morgan Stanley stock?"},
]
generate_chat_response(messages)
# Out:
# I'm sorry, but as an AI assistant, I don't have real-time data. The price of Morgan Stanley stock can vary and is subject to change throughout the trading day. I recommend checking a financial website or contacting your broker for the most up-to-date information on the stock price.

# %%
messages=[
    {"role": "system", "content": 
     """
        Given the following SQL tables, your job is to write queries given a user’s request.

        CREATE TABLE Orders (
        OrderID int,
        CustomerID int,
        OrderDate datetime,
        OrderTime varchar(8),
        PRIMARY KEY (OrderID)
        );

        CREATE TABLE OrderDetails (
        OrderDetailID int,
        OrderID int,
        ProductID int,
        Quantity int,
        PRIMARY KEY (OrderDetailID)
        );

        CREATE TABLE Products (
        ProductID int,
        ProductName varchar(50),
        Category varchar(50),
        UnitPrice decimal(10, 2),
        Stock int,
        PRIMARY KEY (ProductID)
        );

        CREATE TABLE Customers (
        CustomerID int,
        FirstName varchar(50),
        LastName varchar(50),
        Email varchar(100),
        Phone varchar(20),
        PRIMARY KEY (CustomerID)
        );
     """},
    {"role": "user", "content": "Write a SQL query which computes the average total order value for all orders on 2023-04-01. "}
]

generate_chat_response(messages)
# Out:
# SELECT AVG(Quantity * UnitPrice) AS AverageTotalOrderValue
# FROM Orders o
# JOIN OrderDetails od ON o.OrderID = od.OrderID
# JOIN Products p ON od.ProductID = p.ProductID
# WHERE OrderDate = '2023-04-01';

# %%
messages=[
    {"role": "system", "content": 
     """Given the following COBOL code, your job is to summarize the code in plain English.


       **************************************************************************
      * CATEGORY.: HPMS COBOL PROGRAMS
      * GROUP....: COBOL
      * AUTHOR...: LANCE HAYNIE <LANCE@HAYNIEMAIL.COM>
      * DATE.....: 2017-10-02
      * PURPOSE..: TEST LOG REPORT
      **************************************************************************
      * MODIFICATIONS
      * 2017-10-02 - LHAYNIE - INITIAL VERSION
      **************************************************************************
       IDENTIFICATION DIVISION.
       PROGRAM-ID.  TLOGRPT.
      **************************************************************************
       ENVIRONMENT DIVISION.
       INPUT-OUTPUT SECTION.
       FILE-CONTROL.
           SELECT INFILE ASSIGN TO TLOG.
           SELECT OUTFILE ASSIGN TO RPTFILE.
       DATA DIVISION.
       FILE SECTION.
       FD INFILE
           RECORDING MODE F.
       COPY TLOG.
       FD OUTFILE
           RECORDING MODE V.
       01  OUTFILE-RECORD              PIC X(200).
       WORKING-STORAGE SECTION.
       01  WS-CURRENT-DATE.
           05  WS-YEAR                 PIC 9(4).
           05  WS-MONTH                PIC 9(2).
           05  WS-DAY                  PIC 9(2).
           05  WS-HOURS                PIC 9(2).
           05  WS-MINUTES              PIC 9(2).
           05  WS-SECONDS              PIC 9(2).
           05  WS-HUND-SECOND          PIC 9(2).
           05  WS-GMT                  PIC X(5).
       01  OUT-RECORD.
           05  ID-OUT                  PIC X(6).
           05  FILLER                  PIC X(2)
               VALUE  SPACES.
           05  DATE-OUT.
               10  YEAR-OUT            PIC X(4).
               10  FILLER              PIC X
                   VALUE '-'.
               10  MONTH-OUT           PIC X(2).
               10  FILLER              PIC X
                   VALUE '-'.
               10  DAY-OUT             PIC X(2).
           05  FILLER                  PIC X(2)
               VALUE  SPACES.
           05  CATEGORY-OUT            PIC X(28).
           05  FILLER                  PIC X(2)
               VALUE  SPACES.
           05  GROUP-OUT               PIC X(28).
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  AUTHOR-OUT              PIC X(28).
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  SUBJECT-OUT             PIC X(66).
       01  DATE-LINE.
           05  FILLER                  PIC X(12)
               VALUE 'REPORT DATE:'.
           05  FILLER                  PIC X(1)
               VALUE SPACES.
           05  DT-YEAR                 PIC 9(4).
           05  FILLER                  PIC X
               VALUE '/'.
           05  DT-MONTH                PIC 9(2).
           05  FILLER                  PIC X
               VALUE '/'.
           05  DT-DAY                  PIC 9(2).
       01  HEADER-1.
           05  FILLER                  PIC X(100)
               VALUE  'HAYNIE RESEARCH & DEVELOPMENT'.
       01  HEADER-2.
           05  FILLER                  PIC X(100)
               VALUE  'TEST LOG REPORT'.
       01  HEADER-3.
           05  FILLER                  PIC X(8)
               VALUE  'ID'.
           05  FILLER                  PIC X(12)
               VALUE  'DATE'.
           05  FILLER                  PIC X(30)
               VALUE  'CATEGORY'.
           05  FILLER                  PIC X(30)
               VALUE  'GROUP'.
           05  FILLER                  PIC X(30)
               VALUE  'AUTHOR'.
           05  FILLER                  PIC X(66)
               VALUE  'SUBJECT'.
       01  HEADER-4.
           05  FILLER                  PIC X(6)
               VALUE  '------'.
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  FILLER                  PIC X(10)
               VALUE  '----------'.
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(8)
               VALUE '--------'.
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(8)
               VALUE '--------'.
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(8)
               VALUE '--------'.
           05  FILLER                  PIC X(2)
               VALUE SPACES.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(10)
               VALUE '----------'.
           05  FILLER                  PIC X(6)
               VALUE '------'.

       01  SWITCHES.
           05  TLOG-EOF-SWITCH         PIC X(1) VALUE 'N'.
       PROCEDURE DIVISION.
       MAIN-PROGRAM.
           MOVE FUNCTION CURRENT-DATE TO WS-CURRENT-DATE.
           MOVE WS-YEAR TO DT-YEAR.
           MOVE WS-MONTH TO DT-MONTH.
           MOVE WS-DAY TO DT-DAY.
           OPEN INPUT INFILE
                OUTPUT OUTFILE.
           READ INFILE
               AT END
                   MOVE 'Y' TO TLOG-EOF-SWITCH
           END-READ.
           PERFORM PRINT-TITLE
           PERFORM DATA-LOOP
               UNTIL TLOG-EOF-SWITCH = 'Y'
           CLOSE INFILE
                 OUTFILE.
           STOP RUN.
       PRINT-TITLE.
           MOVE HEADER-1 TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           MOVE HEADER-2 TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           MOVE DATE-LINE TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           MOVE SPACES TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           MOVE HEADER-3 TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           MOVE HEADER-4 TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
       DATA-LOOP.
           MOVE TEST-RECORD-ID TO ID-OUT.
           MOVE TEST-YEAR TO YEAR-OUT.
           MOVE TEST-MONTH TO MONTH-OUT.
           MOVE TEST-DAY TO DAY-OUT.
           MOVE TEST-CATEGORY TO CATEGORY-OUT.
           MOVE TEST-GROUP TO GROUP-OUT.
           MOVE TEST-AUTHOR TO AUTHOR-OUT.
           MOVE TEST-SUBJECT TO SUBJECT-OUT.
           MOVE OUT-RECORD TO OUTFILE-RECORD.
           WRITE OUTFILE-RECORD.
           READ INFILE
               AT END
                   MOVE 'Y' TO TLOG-EOF-SWITCH
           END-READ.
     """},
    {"role": "user", "content":  "Summarize the COBOL code in three bullet points."}
]

generate_chat_response(messages)
# Out:
# - The code is a COBOL program that generates a test log report.
# - It reads input from a file called TLOG and writes output to a file called RPTFILE.
# - The program retrieves data from the input file and formats it into specific fields in the output file, including the ID, date, category, group, author, and subject.
